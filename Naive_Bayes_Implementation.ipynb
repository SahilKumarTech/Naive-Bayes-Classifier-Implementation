# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# 1. Direct dataset load via GitHub Gist
url = "https://gist.githubusercontent.com/trantuyen082001/1fc2f5c0ad1507f40e721e6d18b34138/raw/heart.csv"
heart = pd.read_csv(url)

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
plt.figure(figsize=(10, 8))
sns.distplot(heart['age'])
plt.show()
# Out:
# /tmp/ipython-input-3130096602.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart['age'])

# %%
heart.shape
# Out:
# (303, 14)

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
heart.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart['sex'].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
heart['sex'].value_counts().keys()
# Out:
# Index([1, 0], dtype='int64', name='sex')

# %%
heart['sex'].value_counts().values
# Out:
# array([207,  96])

# %%
plt.figure(figsize=(3,3))
plt.bar(list(('male', 'female')), list(heart['sex'].value_counts().values), color=('pink', 'blue'))
plt.show()

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
heart['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
plt.figure(figsize=(3,3))
plt.bar(list(('level 0 ', 'level 1 ', 'level 2', 'level 3')),
        list(heart['cp'].value_counts().values), color=('pink', 'blue', 'green', 'yellow'))

plt.show()

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
sns.distplot(heart['chol'])
plt.show()
# Out:
# /tmp/ipython-input-3814806623.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart['chol'])

# %%
heart['output'].value_counts()
# Out:
# output
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
plt.figure(figsize=(3,3))
plt.bar(list(('no', 'yes')),
        list(heart['output'].value_counts().values), color=('red', 'green'))
plt.show()

# %%
X = heart[['age']]
y = heart[['output']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,x_test,y_train,y_test=train_test_split(X,y,random_state=0, test_size=0.3)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb =  MultinomialNB()

# %%
mnb.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MultinomialNB()

# %%
y_pred= mnb.predict(x_test)

# %%
y_test.head(), y_pred[0:5]
# Out:
# (     output
#  225       0
#  152       1
#  228       0
#  201       0
#  52        1,
#  array([1, 1, 1, 1, 1]))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
confusion_matrix (y_test, y_pred)
# Out:
# array([[ 0, 44],
#        [ 0, 47]])

# %%
(49)/(44+47)
# Out:
# 0.5384615384615384

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5164835164835165

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
x = heart[['age',"trtbps","chol"]]
x.head()
# Out:
#    age  trtbps  chol
# 0   63     145   233
# 1   37     130   250
# 2   41     130   204
# 3   56     120   236
# 4   57     120   354

# %%
y = heart[['output']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.4, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
confusion_matrix (y_test, y_pred)
# Out:
# array([[31, 28],
#        [16, 47]])

# %%
(31+47)/(31+47+16+28)
# Out:
# 0.639344262295082

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.639344262295082
